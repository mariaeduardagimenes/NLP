# %% [markdown]
# <a href="https://colab.research.google.com/github/mariaeduardagimenes/NLP/blob/master/TutoriaL_NLP_AEVO_TextGeneration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Text Generation
#
# ## Introdução
#
# As cadeias de Markov podem ser usadas para geração de texto muito básica. Pense em cada palavra em um corpus como um estado. Podemos fazer uma suposição simples de que a próxima palavra depende apenas da palavra anterior - que é a suposição básica de uma cadeia de Markov.
#
# As cadeias de Markov não geram tão bem quanto deep learning, mas é um bom começo.
#
# ## Selecione o texto para imitar
#
# Vamos gerar um texto específico no estilo dos assuntos dos textos retirado do blog AEVO.

# %%
# Leia o corpus, incluindo pontuação!
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                                                   textos  \
# inovacao aberta        Se você já acompanha nossos conteúdos há algum...
# inovacao incremental   O termo inovação incremental ganhou força em 1...
# intraempreendedorismo  As soft skills são habilidades subjetivas, de ...
#
#                                    full_name
# inovacao aberta              Inovação Aberta
# inovacao incremental    Inovação Incremental
# intraempreendedorismo  Intraempreendedorismo

# %%
# Extrair apenas texto de Inovação Incremental 
ii_text = data.textos.loc['inovacao incremental']
ii_text[:200]
# Out:
# 'O termo\xa0inovação incremental\xa0ganhou força em 1939, marcando presença no livro “Business\xa0Cycle” de Joseph Schumpeter, onde foi caracterizado como um tipo de inovação.\xa0\xa0 O conceito é muito similar a fil'

# %% [markdown]
# ## Build a Markov Chain Function
#
# Vamos construir uma função de cadeia de Markov simples que cria um dicionário:
#
# 1. As chaves devem ser todas as palavras do corpus
# 2. Os valores devem ser uma lista das palavras que seguem as chaves

# %%
from collections import defaultdict

def markov_chain(text):
    '''A entrada é uma string de texto e a saída será um dicionário com cada palavra como
        uma chave e cada valor como a lista de palavras que vêm depois da chave no texto.'''
    
    # Tokenize o texto palavra por palavra, incluindo pontuação.
    words = text.split(' ')
    
    # Inicializar um dicionário padrão para conter todas as palavras e as próximas palavras
    m_dict = defaultdict(list)
    
    # Crie uma lista compactada de todos os pares de palavras e coloque-os no formato word: list of next words
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Converter o dicionário padrão de volta em um dicionário
    m_dict = dict(m_dict)
    return m_dict

# %%
# Criar dicionário de inovação incremental e dos outros textos
ii_dict = markov_chain(ii_text)
ii_dict
# Out:
# {'O': ['termo\xa0inovação', 'conceito', 'motivo', 'exemplo'],
#  'termo\xa0inovação': ['incremental\xa0ganhou'],
#  'incremental\xa0ganhou': ['força'],
#  'força': ['em', 'quando'],
#  'em': ['1939,',
#   'produtos,',
#   'uma',
#   'que',
#   'cada',
#   'um',
#   'alto',
#   'jogo!\xa0Em',
#   'inovação,',
#   'inovação',
#   'pesquisas',
#   'empresas',
#   'um'],
#  '1939,': ['marcando'],
#  'marcando': ['presença'],
#  'presença': ['no'],
#  'no': ['livro', 'meu', 'seu'],
#  'livro': ['“Business\xa0Cycle”'],
#  '“Business\xa0Cycle”': ['de'],
#  'de': ['Joseph',
#   'inovação.\xa0\xa0',
#   'melhoria',
#   'forma\xa0sistêmica,',
#   'forma',
#   'processos',
#   'colaboração,',
#   'Programa',
#   'Ideias.\xa0',
#   'pequenas',
#   'inovação',
#   'Programa',
#   'Ideias,',
#   'sugestões',
#   'melhoria',
#   'colaboradores',
#   'brainstorming:',
#   'linha',
#   'frente.\xa0',
#   'produtos,',
#   'inovação),\xa0porém\xa0ela',
#   'melhoria,',
#   'um',
#   'uma',
#   '10',
#   '10',
#   'todos',
#   '10',
#   'custos',
#   'que',
#   'forma',
#   'incerteza',
#   'inovação:',
#   'concorrer,',
#   'valor.\xa0',
#   'ideias',
#   'Inovação,',
#   'visão',
#   'alocação',
#   'recursos',
#   'acordo',
#   'conhecimento',
#   '2005,',
#   'inovação',
#   'alocação',
#   'recursos',
#   'investimentos.',
#   'inovação',
#   'superá-lo',
#   'linha',
#   'frente',
#   'melhoria',
#   'uma',
#   'custos\xa0e',
#   'Programa',
#   'Ideias',
#   'Ideias'],
#  'Joseph': ['Schumpeter,'],
#  'Schumpeter,': ['onde'],
#  'onde': ['foi'],
#  'foi': ['caracterizado'],
#  'caracterizado': ['como'],
#  'como': ['um',
#   'Kaizen,',
#   'o',
#   'o',
#   'melhorá-los.',
#   'desperdiçar',
#   'a\xa0organização\xa0estrutura\xa0seu',
#   'o'],
#  'um': ['tipo',
#   'método',
#   'processo\xa0inovador,',
#   'exemplo:\xa0',
#   'processo',
#   'pouco',
#   'alto',
#   'novo',
#   'mercado',
#   'investimento',
#   'abacaxi,',
#   'produto',
#   'mercado',
#   'time',
#   'processo',
#   'Programa'],
#  'tipo': ['de', 'de', 'de'],
#  'inovação.\xa0\xa0': ['O'],
#  'conceito': ['é'],
#  'é': ['muito',
#   'uma',
#   'realizado',
#   'claro:',
#   'igual',
#   'executado',
#   'entender',
#   'preciso',
#   'entender',
#   'um',
#   'matá-lo.',
#   'validado',
#   'incorporado',
#   'uma'],
#  'muito': ['similar', 'experiente', 'bem', 'benéfico,'],
#  'similar': ['a'],
#  'a': ['filosofia\xa0japonesa',
#   'estratégia',
#   'um',
#   'organização',
#   'visão',
#   'outros',
#   'rotina',
#   'jornada',
#   'remuneração',
#   'inovação',
#   'escala',
#   'seu',
#   'inovação',
#   'incorporação',
#   'imagem',
#   'inovação',
#   'estratégia',
#   'coisas',
#   'Google',
#   'possível',
#   'todo',
#   'inovação',
#   'AEVO',
#   'inovação'],
#  'filosofia\xa0japonesa': ['de'],
#  'melhoria': ['contínua,', 'que', 'de'],
#  'contínua,': ['conhecida'],
#  'conhecida': ['como'],
#  'Kaizen,': ['que'],
#  'que': ['prevê',
#   'gerem',
#   'estão',
#   'ninguém',
#   'o',
#   'a',
#   'o',
#   'a',
#   'isso',
#   'demos',
#   'quanto',
#   'momento',
#   'nós',
#   'não',
#   'são',
#   'o',
#   'entra',
#   'geram',
#   'o',
#   'estão',
#   'o',
#   'a',
#   'eu',
#   'visa',
#   '80%'],
#  'prevê': ['um'],
#  'método': ['para'],
#  'para': ['executar', 'o', 'todos\xa0(40', 'você', 'grande', 'o', 'implantar'],
#  'executar': ['a'],
#  'estratégia': ['de', 'de', 'que'],
#  'forma\xa0sistêmica,': ['envolvendo'],
#  'envolvendo': ['todos', 'todos'],
#  'todos': ['os', 'os', 'esses', 'os', 'os'],
#  'os': ['colaboradores',
#   'colaboradores',
#   'dias',
#   'dias',
#   'seus',
#   'investimentos',
#   'colaboradores',
#   'colaboradores',
#   'passos'],
#  'colaboradores': ['da',
#   'geralmente',
#   'de',
#   'são',
#   'poupariam',
#   'poupariam',
#   'de',
#   'da'],
#  'da': ['organização.\xa0\xa0',
#   'empresa',
#   'escala,',
#   'execução',
#   'escala,',
#   'Google),',
#   'organização:\xa0',
#   'sua',
#   'estratégia,',
#   'escala',
#   'organização.\xa0'],
#  'organização.\xa0\xa0': ['Hoje,\xa0a'],
#  'Hoje,\xa0a': ['inovação'],
#  'inovação': ['de',
#   'incremental',
#   'é',
#   'incremental',
#   'incremental',
#   'incremental\xa0é\xa0pouco',
#   'tecnológica',
#   'incremental.',
#   'pode',
#   'incremental\xa0faz',
#   'da',
#   'incremental',
#   'implica',
#   'incremental',
#   'incremental'],
#  'forma': ['incremental\xa0é', 'incremental'],
#  'incremental\xa0é': ['amplamente'],
#  'amplamente': ['conhecida\xa0e'],
#  'conhecida\xa0e': ['tem'],
#  'tem': ['ganhado\xa0relevância', 'um'],
#  'ganhado\xa0relevância': ['à'],
#  'à': ['luz', 'frente', 'luz', 'um', 'luz'],
#  'luz': ['de', 'da', 'da'],
#  'processos': ['inovadores\xa0com', 'e', 'e', 'e'],
#  'inovadores\xa0com': ['alto'],
#  'alto': ['grau', 'potencial\xa0de', 'crescimento,\xa0ele'],
#  'grau': ['de'],
#  'colaboração,': ['como'],
#  'o': ['de',
#   'de',
#   'nosso',
#   'seu',
#   'seu',
#   'tempo\xa0reduzido\xa0em',
#   'mais',
#   'seu',
#   'melhor',
#   'que',
#   'produto',
#   'produto.\xa0',
#   'seu',
#   'seu',
#   'framework',
#   'investimento',
#   'nível',
#   'presidente',
#   'carro-chefe',
#   'centro',
#   'conhecimento',
#   'seu',
#   'investimento',
#   'de'],
#  'Programa': ['de', 'de', 'de', 'de'],
#  'Ideias.\xa0': ['A'],
#  'A': ['inovação', 'inovação', 'inovação'],
#  'incremental': ['é', 'pode', 'tem', 'se', 'é', 'algo', 'na'],
#  'uma': ['série',
#   'empresa.',
#   'sugestão',
#   'fábrica.\xa0',
#   'aposta',
#   'aposta',
#   'ampla',
#   'estratégia',
#   'vez',
#   'organização'],
#  'série': ['de'],
#  'pequenas': ['melhorias'],
#  'melhorias': ['em'],
#  'produtos,': ['processos', 'processos', 'processos'],
#  'e': ['serviços',
#   'serviços',
#   'perguntas',
#   'quanto',
#   'está',
#   'torna-se',
#   'com',
#   'serviços.\xa0',
#   'já',
#   'anúncios',
#   'Google',
#   'dinheiro',
#   'anúncios',
#   'quer',
#   'aplicar'],
#  'serviços': ['existentes', 'da'],
#  'existentes': ['em'],
#  'empresa.': ['Quando'],
#  'Quando': ['esse', 'trazemos'],
#  'esse': ['tipo'],
#  'realizado': ['alinhado', 'por'],
#  'alinhado': ['a'],
#  'processo\xa0inovador,': ['como'],
#  'Ideias,': ['podemos'],
#  'podemos': ['alcançar', 'envolver', 'perceber', 'apostar'],
#  'alcançar': ['resultados'],
#  'resultados': ['ainda', 'com'],
#  'ainda': ['mais\xa0significativos.\xa0'],
#  'mais\xa0significativos.\xa0': ['O'],
#  'motivo': ['é'],
#  'claro:': ['podemos'],
#  'envolver': ['toda'],
#  'toda': ['a'],
#  'organização': ['na', 'está'],
#  'na': ['idealização', 'imagem', 'sua'],
#  'idealização': ['de'],
#  'sugestões': ['de'],
#  'gerem': ['valor'],
#  'valor': ['para'],
#  'nosso': ['negócio.\xa0Deste', 'negócio.\xa0', 'tempo', 'tempo'],
#  'negócio.\xa0Deste': ['modo,'],
#  'modo,': ['obtemos'],
#  'obtemos': ['a'],
#  'visão': ['de', 'de'],
#  'geralmente': ['esquecidos'],
#  'esquecidos': ['nas'],
#  'nas': ['reuniões'],
#  'reuniões': ['de'],
#  'brainstorming:': ['os'],
#  'linha': ['de', 'de'],
#  'frente.\xa0': ['Esses'],
#  'Esses': ['colaboradores'],
#  'são': ['muitas', 'eles', 'e', 'os'],
#  'muitas': ['vezes', 'hipóteses'],
#  'vezes': ['subestimados,'],
#  'subestimados,': ['mas'],
#  'mas': ['são'],
#  'eles': ['que'],
#  'estão': ['à', 'todos'],
#  'frente': ['de', 'à', 'ao', 'para'],
#  'empresa': ['todos'],
#  'dias': ['e,', 'lidando'],
#  'e,': ['portanto,', 'neste'],
#  'portanto,': ['entendem'],
#  'entendem': ['melhor'],
#  'melhor': ['do', 'é'],
#  'do': ['que',
#   'seu',
#   'nosso',
#   'nosso',
#   'nosso',
#   'presidente',
#   'seu',
#   'seu',
#   'potencial'],
#  'ninguém': ['como'],
#  'melhorá-los.': ['A'],
#  'pode': ['ser', 'ser', 'ser', 'ser'],
#  'ser': ['subestimada', 'observado', 'priorizado', 'dedicado', 'muito'],
#  'subestimada': ['pelos\xa0resultados'],
#  'pelos\xa0resultados': ['com'],
#  'com': ['menor', 'resultado', 'bastante', 'os', 'o', 'o', 'redução', 'a'],
#  'menor': ['impacto'],
#  'impacto': ['(se'],
#  '(se': ['comparada'],
#  'comparada': ['a'],
#  'outros': ['tipos'],
#  'tipos': ['de'],
#  'inovação),\xa0porém\xa0ela': ['ganha'],
#  'ganha': ['força'],
#  'quando': ['observada', 'investir,', 'o', 'executada'],
#  'observada': ['à'],
#  'escala,': ['incorporando-se', 'podemos'],
#  'incorporando-se': ['ao\xa0mindset\xa0e'],
#  'ao\xa0mindset\xa0e': ['a'],
#  'rotina': ['das'],
#  'das': ['organizações.\xa0', 'perguntas,'],
#  'organizações.\xa0': ['Aqui'],
#  'Aqui': ['vai'],
#  'vai': ['um'],
#  'exemplo:\xa0': ['Imagine'],
#  'Imagine': ['que'],
#  'seu': ['time',
#   'processo',
#   'time,',
#   'negócio\xa0ou',
#   'produto',
#   'produto',
#   'produto\xa0ainda\xa0é',
#   'projeto',
#   'Core',
#   'carro-chefe',
#   'Core',
#   'tempo',
#   'Core',
#   'produto',
#   'produto'],
#  'time': ['implantou', 'muito'],
#  'implantou': ['apenas'],
#  'apenas': ['uma'],
#  'sugestão': ['de'],
#  'melhoria,': ['poupando'],
#  'poupando': ['10'],
#  '10': ['minutos', 'semanas', 'semanas', 'semanas,'],
#  'minutos': ['da', 'poupados.\xa0', 'poupados', 'reduzidos.\xa0'],
#  'execução': ['individual'],
#  'individual': ['diária'],
#  'diária': ['de'],
#  'processo': ['realizado', 'é', 'inovador,'],
#  'por': ['100', 'dia),', '1.000', 'vantagem', 'sua', 'conhecimento'],
#  '100': ['colaboradores\xa0dentro', 'colaboradores'],
#  'colaboradores\xa0dentro': ['de'],
#  'fábrica.\xa0': ['Se'],
#  'Se': ['nós', 'a'],
#  'nós': ['considerarmos', 'lançamos'],
#  'considerarmos': ['que'],
#  'jornada': ['semanal'],
#  'semanal': ['desses', 'de'],
#  'desses': ['funcionários'],
#  'funcionários': ['é'],
#  'igual': ['para'],
#  'todos\xa0(40': ['horas\xa0por'],
#  'horas\xa0por': ['semana,'],
#  'semana,': ['8'],
#  '8': ['horas'],
#  'horas': ['por'],
#  'dia),': ['ao'],
#  'ao': ['longo', 'seu', 'meu'],
#  'longo': ['de'],
#  'semanas': ['teríamos', 'seria'],
#  'teríamos': ['aproximadamente'],
#  'aproximadamente': ['50', '500', 'R$105.000,00\xa0'],
#  '50': ['mil', 'mil'],
#  'mil': ['minutos', 'minutos', 'minutos'],
#  'poupados.\xa0': ['Agora,'],
#  'Agora,': ['considere', 'quando', 'se\xa0você'],
#  'considere': ['que'],
#  'executado': ['por'],
#  '1.000': ['colaboradores!', 'colaboradores'],
#  'colaboradores!': ['Os'],
#  'Os': ['50'],
#  'poupados': ['seriam'],
#  'seriam': ['alcançados\xa0logo\xa0no'],
#  'alcançados\xa0logo\xa0no': ['primeiro'],
#  'primeiro': ['dia,', 'lugar,'],
#  'dia,': ['enquanto'],
#  'enquanto': ['o\xa0resultado', '1.000'],
#  'o\xa0resultado': ['de'],
#  'seria': ['aproximadamente', 'como'],
#  '500': ['mil'],
#  'reduzidos.\xa0': ['E'],
#  'E': ['se', 'então'],
#  'se': ['formos', 'torna', 'encontra.\xa0\xa0', 'o', 'torna'],
#  'formos': ['um'],
#  'pouco': ['além,'],
#  'além,': ['considerando\xa0R$'],
#  'considerando\xa0R$': ['500,00'],
#  '500,00': ['a'],
#  'remuneração': ['média'],
#  'média': ['semanal'],
#  'esses': ['colaboradores,\xa0nós'],
#  'colaboradores,\xa0nós': ['poderíamos'],
#  'poderíamos': ['transformar'],
#  'transformar': ['o'],
#  'tempo\xa0reduzido\xa0em': ['dinheiro'],
#  'dinheiro': ['poupado!', 'no'],
#  'poupado!': [''],
#  '': ['Dessa', 'Logo,'],
#  'Dessa': ['forma,'],
#  'forma,': ['ao\xa0longo'],
#  'ao\xa0longo': ['de'],
#  'semanas,': ['100'],
#  'poupariam': ['R$10.500,00,', 'aproximadamente'],
#  'R$10.500,00,': ['enquanto'],
#  'R$105.000,00\xa0': ['Independente'],
#  'Independente': ['da'],
#  'perceber': ['que', 'que'],
#  'potencial\xa0de': ['redução'],
#  'redução': ['de', 'de'],
#  'custos': ['–'],
#  '–': ['tenho', 'envolvendo'],
#  'tenho': ['certeza'],
#  'certeza': ['de'],
#  'isso': ['foi\xa0perceptível'],
#  'foi\xa0perceptível': ['para'],
#  'você': ['nos', 'já', 'precisa', 'não'],
#  'nos': ['dois', 'contou'],
#  'dois': ['exemplos'],
#  'exemplos': ['que'],
#  'demos': ['acima.\xa0\xa0'],
#  'acima.\xa0\xa0': ['Porém'],
#  'Porém': ['o'],
#  'mais': ['importante', 'obrigatório.', 'sentido'],
#  'importante': ['é'],
#  'entender': ['que', 'quando', 'se', 'como\xa0priorizar', 'quais'],
#  'quanto': ['maior', 'investir', 'eu'],
#  'maior': ['a'],
#  'escala': ['do', 'pode'],
#  'time,': ['inovar'],
#  'inovar': ['de'],
#  'torna': ['mais', 'sua'],
#  'obrigatório.': ['Do'],
#  'Do': ['contrário,'],
#  'contrário,': ['seria'],
#  'desperdiçar': ['recursos'],
#  'recursos': ['conscientemente.\xa0', 'por', 'do'],
#  'conscientemente.\xa0': ['Para'],
#  'Para': ['entender', 'entender', 'tornar'],
#  'investir,': ['é'],
#  'preciso': ['conhecer'],
#  'conhecer': ['em'],
#  'momento': ['a'],
#  'negócio\xa0ou': ['seu'],
#  'produto': ['se', 'ou', 'frente', 'que', 'é', 'pelo', 'à'],
#  'encontra.\xa0\xa0': ['Sempre'],
#  'Sempre': ['que'],
#  'lançamos': ['um'],
#  'novo': ['produto'],
#  'ou': ['serviço,', 'grupo\xa0de', 'seja,', 'seja,', 'proposta', 'seja,'],
#  'serviço,': ['existem'],
#  'existem': ['muitas'],
#  'hipóteses': ['e'],
#  'perguntas': ['sem'],
#  'sem': ['respostas.'],
#  'respostas.': ['Esse\xa0alto\xa0grau'],
#  'Esse\xa0alto\xa0grau': ['de'],
#  'incerteza': ['sugere'],
#  'sugere': ['que\xa0você'],
#  'que\xa0você': ['precisa'],
#  'precisa': ['validar', 'garantir'],
#  'validar': ['seu'],
#  'mercado': ['ou', 'em'],
#  'grupo\xa0de': ['consumidores.\xa0Neste\xa0caso,\xa0o'],
#  'consumidores.\xa0Neste\xa0caso,\xa0o': ['seu'],
#  'produto\xa0ainda\xa0é': ['uma'],
#  'aposta': ['(como', 'se'],
#  '(como': ['pode'],
#  'observado': ['na'],
#  'imagem': ['acima),', 'acima,\xa0podemos'],
#  'acima),': ['ou'],
#  'seja,': ['um', 'um', 'aquilo'],
#  'investimento': ['com', 'em', 'num'],
#  'resultado': ['futuro.\xa0\xa0\xa0'],
#  'futuro.\xa0\xa0\xa0': ['Desse'],
#  'Desse': ['modo,\xa0a'],
#  'modo,\xa0a': ['inovação'],
#  'incremental\xa0é\xa0pouco': ['vantajosa,\xa0uma'],
#  'vantajosa,\xa0uma': ['vez\xa0que\xa0a'],
#  'vez\xa0que\xa0a': ['sua'],
#  'sua': ['prioridade', 'vaca', 'vaca', 'vez,', 'organização.', 'organização,'],
#  'prioridade': ['é'],
#  'projeto': ['é'],
#  'abacaxi,': ['ou'],
#  'não': ['deu', 'seja', 'faria'],
#  'deu': ['certo'],
#  'certo': ['e,'],
#  'neste': ['caso,'],
#  'caso,': ['o'],
#  'matá-lo.': ['Leia'],
#  'Leia': ['também:'],
#  'também:': ['Horizontes'],
#  'Horizontes': ['de', 'de'],
#  'inovação:': ['o'],
#  'investir': ['em', 'no'],
#  'cada': ['um?\xa0'],
#  'um?\xa0': ['Agora,'],
#  'validado': ['e'],
#  'está': ['em', 'em', 'nesses'],
#  'crescimento,\xa0ele': ['é'],
#  'incorporado': ['ao'],
#  'Core': ['Business',
#   'Business\xa0seja',
#   'Business',
#   'Business?\xa0',
#   'Business\xa0(pesquisas'],
#  'Business': ['e', '(minha'],
#  'torna-se': ['sua'],
#  'vaca': ['leiteira!\xa0Aqui,', 'leiteira', 'leiteira),'],
#  'leiteira!\xa0Aqui,': ['você'],
#  'já': ['terá', 'percebemos', 'validei\xa0frente'],
#  'terá': ['respostas'],
#  'respostas': ['para'],
#  'grande': ['parte'],
#  'parte': ['das'],
#  'perguntas,': ['obtendo'],
#  'obtendo': ['um'],
#  'experiente': ['e'],
#  'bastante': ['conhecimento'],
#  'conhecimento': ['sobre', 'do', 'obtido', 'deles'],
#  'sobre': ['o', 'a'],
#  'produto.\xa0': ['Porém,\xa0quando'],
#  'Porém,\xa0quando': ['uma'],
#  'leiteira': ['(Core'],
#  '(Core': ['Business),'],
#  'Business),': ['muita'],
#  'muita': ['coisa', 'assertividade,'],
#  'coisa': ['está'],
#  'jogo!\xa0Em': ['primeiro'],
#  'lugar,': ['você'],
#  'garantir': ['que'],
#  'carro-chefe': ['não', 'da'],
#  'seja': ['defasado', 'por'],
#  'defasado': ['pelo'],
#  'pelo': ['mercado,\xa0já\xa0que', 'mercado,'],
#  'mercado,\xa0já\xa0que': ['este'],
#  'este': ['encontrará'],
#  'encontrará': ['formas'],
#  'formas': ['de', 'de'],
#  'concorrer,': ['seja'],
#  'vantagem': ['competitiva,'],
#  'competitiva,': ['inovação'],
#  'tecnológica': ['ou'],
#  'proposta': ['de'],
#  'valor.\xa0': ['É'],
#  'É': ['aí'],
#  'aí': ['que'],
#  'entra': ['a'],
#  'incremental.': ['Essa,'],
#  'Essa,': ['por'],
#  'vez,': ['garantirá'],
#  'garantirá': ['a'],
#  'incorporação': ['de'],
#  'ideias': ['que'],
#  'geram': ['valor,'],
#  'valor,': ['garantindo'],
#  'garantindo': ['que'],
#  'Business\xa0seja': ['continuamente'],
#  'continuamente': ['melhorado\xa0por', 'o'],
#  'melhorado\xa0por': ['aqueles'],
#  'aqueles': ['que'],
#  'lidando': ['frente\xa0a\xa0frente'],
#  'frente\xa0a\xa0frente': ['com'],
#  'seus': ['produtos,', 'resultados'],
#  'serviços.\xa0': ['Para'],
#  'como\xa0priorizar': ['os'],
#  'investimentos': ['em'],
#  'inovação,': ['a\xa0Mckinsey\xa0&\xa0Company\xa0criou'],
#  'a\xa0Mckinsey\xa0&\xa0Company\xa0criou': ['o'],
#  'framework': ['3'],
#  '3': ['Horizontes'],
#  'Inovação,': ['dando-nos'],
#  'dando-nos': ['uma'],
#  'ampla': ['de'],
#  'alocação': ['de', 'de'],
#  'negócio.\xa0': ['Observando'],
#  'Observando': ['a'],
#  'acima,\xa0podemos': ['perceber'],
#  'priorizado': ['de'],
#  'acordo': ['com'],
#  'nível': ['de'],
#  'obtido': ['por\xa0negócios:\xa0'],
#  'por\xa0negócios:\xa0': ['Nós'],
#  'Nós': ['já'],
#  'percebemos': ['que'],
#  'incremental\xa0faz': ['mais'],
#  'sentido': ['quando'],
#  'executada': ['frente'],
#  'meu': ['Core', 'Core'],
#  '(minha': ['vaca'],
#  'leiteira),': ['ou'],
#  'aquilo': ['que'],
#  'eu': ['possuo', 'devo'],
#  'possuo': ['histórico,\xa0tenho\xa0conhecimento'],
#  'histórico,\xa0tenho\xa0conhecimento': ['e'],
#  'validei\xa0frente': ['ao\xa0mercado.\xa0'],
#  'ao\xa0mercado.\xa0': ['Mas'],
#  'Mas': ['quanto'],
#  'devo': ['investir'],
#  'Business?\xa0': ['Em'],
#  'Em': ['meados'],
#  'meados': ['de'],
#  '2005,': ['o'],
#  'presidente': ['da\xa0Alphabet\xa0Inc.', 'da\xa0Alphabet\xa0Inc.'],
#  'da\xa0Alphabet\xa0Inc.': ['(holding', 'ilustra'],
#  '(holding': ['dona'],
#  'dona': ['da'],
#  'Google),': ['nos'],
#  'contou': ['sobre'],
#  'organização:\xa0': ['“Gastamos'],
#  '“Gastamos': ['70%'],
#  '70%': ['do', 'do'],
#  'tempo': ['em', 'deve', 'e', 'recorde.\xa0'],
#  'pesquisas': ['e'],
#  'anúncios': ['principais.', 'principais),'],
#  'principais.': ['Gastamos'],
#  'Gastamos': ['20%'],
#  '20%': ['em'],
#  'empresas': ['adjacentes:'],
#  'adjacentes:': ['Google'],
#  'Google': ['Notícias,', 'Earth', 'Local.', 'investe'],
#  'Notícias,': ['Google'],
#  'Earth': ['e'],
#  'Local.': ['E'],
#  'então': ['10%'],
#  '10%': ['do'],
#  'deve': ['ser'],
#  'dedicado': ['a'],
#  'coisas': ['verdadeiramente'],
#  'verdadeiramente': ['novas.”\xa0'],
#  'novas.”\xa0': ['O'],
#  'exemplo': ['de'],
#  'ilustra': ['muito'],
#  'bem': ['como'],
#  'a\xa0organização\xa0estrutura\xa0seu': ['portfólio'],
#  'portfólio': ['de'],
#  'investimentos.': ['Se'],
#  'investe': ['70%'],
#  'Business\xa0(pesquisas': ['e'],
#  'principais),': ['por\xa0que'],
#  'por\xa0que': ['você'],
#  'faria': ['isso?\xa0'],
#  'isso?\xa0': ['A'],
#  'visa': ['melhorar'],
#  'melhorar': ['continuamente'],
#  'organização.': ['A\xa0não'],
#  'A\xa0não': ['adesão'],
#  'adesão': ['desse'],
#  'desse': ['tipo', 'conteúdo'],
#  'implica': ['também'],
#  'também': ['a'],
#  'possível': ['defasagem'],
#  'defasagem': ['do'],
#  'mercado,': ['que\xa0buscará'],
#  'que\xa0buscará': ['formas'],
#  'superá-lo': ['a'],
#  'todo': ['momento.\xa0'],
#  'momento.\xa0': ['Quando'],
#  'trazemos': ['os'],
#  'centro': ['da'],
#  'estratégia,': ['ganhamos'],
#  'ganhamos': ['muita'],
#  'assertividade,': ['uma'],
#  'vez': ['que'],
#  '80%': ['do'],
#  'potencial': ['de'],
#  'nesses': ['colaboradores.'],
#  'colaboradores.': [''],
#  'Logo,': ['o'],
#  'deles': ['com'],
#  'benéfico,': ['multiplicando'],
#  'multiplicando': ['seus'],
#  'custos\xa0e': ['pagando'],
#  'pagando': ['o'],
#  'num': ['tempo'],
#  'recorde.\xa0': ['Para'],
#  'tornar': ['a'],
#  'algo': ['contínuo,'],
#  'contínuo,': ['podemos'],
#  'apostar': ['em'],
#  'inovador,': ['como'],
#  'Ideias': ['–', 'com'],
#  'organização.\xa0': ['Agora,'],
#  'se\xa0você': ['gostou'],
#  'gostou': ['desse'],
#  'conteúdo': ['e'],
#  'quer': ['entender'],
#  'quais': ['são'],
#  'passos': ['para'],
#  'implantar': ['um'],
#  'AEVO': ['e'],
#  'aplicar': ['a'],
#  'organização,': ['clique\xa0neste'],
#  'clique\xa0neste': ['link.\xa0']}

# %% [markdown]
# ## Crie um gerador de texto
#
# Vamos criar uma função que gere frases. Terá duas coisas como entradas:
#
# 1. O dicionário que você acabou de criar
# 2. O número de palavras que você deseja gerar

# %%
import random

def generate_sentence(chain, count=15):
    '''Insira um dicionário no formato de chave = palavra atual, valor = lista das próximas palavras
        junto com o número de palavras que você gostaria de ver em sua frase gerada.'''

    # Primeira palavra em maiúsculo
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Gerar a segunda palavra da value list. Setar a palavra nova como a primeira palavra. Repetir.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # Terminar com um ponto
    sentence += '.'
    return(sentence)

# %%
generate_sentence(ii_dict)
# Out:
# 'Respostas para o conhecimento do potencial de forma\xa0sistêmica, envolvendo todos os colaboradores de ideias que.'

# %%
# Extrair apenas textos de Inovação Aberto
ia_text = data.textos.loc['inovacao aberta']
ia_text[:200]
# Out:
# 'Se você já acompanha nossos conteúdos há algum tempo, sabe a importância do mindset de inovação aberta para construir não somente o agora, como também o futuro.\xa0 O nome dessa estratégia é Ambidestria '

# %%
from collections import defaultdict


    '''A entrada é uma string de texto e a saída será um dicionário com cada palavra como uma chave e cada valor como a lista de palavras que vêm após a chave no texto'''
    
    # Tokenize o texto por palavra, embora incluindo pontuação
    words = text.split(' ')
    
    # Inicialize um dicionário padrão para conter todas as palavras e as próximas palavras
    m_dict = defaultdict(list)
    
    # Crie uma lista compactada de todos os pares de palavras e coloque-os no formato word: list of next words
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Converta o dicionário padrão de volta em um dicionário
    m_dict = dict(m_dict)
    return m_dict


# Crie o dicionário para Inovação Aberta, dê uma olhada nele
ia_dict = markov_chain(ia_text)
ia_dict


import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize a primeira palavra
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Gere a segunda palavra da lista de valores. Defina a nova palavra como a primeira palavra. Repetir.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # Termine com um ponto final
    sentence += '.'
    return(sentence)

generate_sentence(ia_dict)
# Out:
# 'Incerteza e matéria prima, onde o que isso não surgia tempo para o Movimento Estar.'

# %%
# Extrair apenas textos de Intraempreendedorismo
ie_text = data.textos.loc['intraempreendedorismo']
ie_text[:200]
# Out:
# 'As\xa0soft\xa0skills\xa0são habilidades subjetivas, de difícil identificação e diretamente relacionadas à inteligência emocional das pessoas.\xa0 Em tradução livre, o termo —\xa0soft\xa0skills\xa0—\xa0 significa: habilidades'

# %%
from collections import defaultdict

def markov_chain(text):
    '''A entrada é uma string de texto e a saída será um dicionário com cada palavra como uma chave e cada valor como a lista de palavras que vêm após a chave no texto.'''
    
    
    words = text.split(' ')
    
    
    m_dict = defaultdict(list)
    

    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)


    m_dict = dict(m_dict)
    return m_dict



ie_dict = markov_chain(ia_text)
ie_dict


import random

def generate_sentence(chain, count=15):
    '''Insira um dicionário no formato de chave = palavra atual, valor = lista das próximas palavras junto com o número de palavras que você gostaria de ver em sua frase gerada.'''

   
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

   
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

   
    sentence += '.'
    return(sentence)

generate_sentence(ie_dict)
# Out:
# 'Adaptar e a parte,\xa0mas criatividade está diretamente relacionadas à inteligência emocional, o profissional empreendedor deveria.'
